# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/jay/github/시도별 전출입 인구수.xlsx')

# %%
df.drop(index=0, inplace=True)

# %%
df[df['전입지별'] == '서울특별시']
# Out:
#     전출지별   전입지별     1970     1971     1972     1973     1974     1975  \
# 2    NaN  서울특별시  1742813  1671705  1349333  1831858  2050392  3396662
# 20   NaN  서울특별시  1232619  1158556   985945  1345508  1511726  2401970
# 38   NaN  서울특별시    24263    30144    18260    24251    30284    59914
# 56   NaN  서울특별시        -        -        -        -        -        -
# 74   NaN  서울특별시        -        -        -        -        -        -
# 92   NaN  서울특별시        -        -        -        -        -        -
# 110  NaN  서울특별시        -        -        -        -        -        -
# 128  NaN  서울특별시        -        -        -        -        -        -
# 146  NaN  서울특별시        -        -        -        -        -        -
# 164  NaN  서울특별시    95388    95423    90470   107177   107518   207641
# 182  NaN  서울특별시    34563    38588    32497    40922    42649    74065
# 200  NaN  서울특별시    37625    39139    29513    36260    40154    72525
# ...
