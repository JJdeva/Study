# %% [markdown]
# # Do it Pandas 공부
# ## Date : 2020-09-28_ Day2_2

# %% [markdown]
# ## 04 - 1. 데이터 시각화가 필요한 이유

# %% [markdown]
# ### 앤스콤
# - seaborn 라이브러리에 포함되어 있음
# - 만약 평균, 분산, 상관관계, 회귀선 등의 통계 수치가 같아도 그래프 형태는 다를 수 있음
# - 수치만 보고 판단하지말고 항상 시각화해보고 눈으로 확인해볼 것!!!

# %%
import seaborn as sns

# %%
anscombe = sns.load_dataset('anscombe')
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']
dataset_1.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
plt.plot(dataset_1['x'], dataset_1['y']) # 기본적으로는 선으로 그린다.

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o') # 점으로 그리고 싶으면 o를 넣자. 
# matlab의 plot과 기능이 비슷허네

# %% [markdown]
# #### matplotlib 라이브러리로 그래프 그리기
# 1. 전체 그래프가 위치할 기본 틀을 만든다.
# 2. 그래프를 그려 넣을 그래프 격자를 만든다.
# 3. 그런 다음 격자에 그래프를 하나씩 추가한다. 격자에 그래프가 추가되는 순서는 왼쪽에서 오른쪽 방향.
# 4. 만약 격자의 첫 번째 행이 꽉 차면 두번째 행에 그래프를 그려 넣는다.

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
fig = plt.figure() # 그래프 격자를 만든다.
#subplot 만들기
axes1 = fig.add_subplot(2,2,1) # 매트랩 서브플랏하고 같네
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3) 
axes4 = fig.add_subplot(2,2,4)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')
fig

# %% [markdown]
# #### 타이틀 넣기
# - set_title()

# %%
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')
fig

# %% [markdown]
# #### 전체 fig 안에도 제목을 넣자
# - suptitle 메서드

# %%
fig.suptitle('Anscombe Data')
fig

# %% [markdown]
# #### 레이아웃 조절
# - 위 그래프 보면 중간에 그래프 타이틀과 그래프 x축 항목이 겹쳐 보임. 이를 조절 해주자

# %%
fig.tight_layout()
fig
